# %%
import google.generativeai as ai

# %%
f1 = open(r"C:\Users\rames\Documents\GEN AI INTERNSHIP PROJECTS\Key.txt")

key = f1.read()

# %%
key = "AIzaSyCBxCLJLoZ-s2pO7aVgrTVir956Kj43hiI"

# %%
ai.configure(api_key=key)

# %% [markdown]
# ## Models

# %%
for model in ai.list_models():
    print(model.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/learnlm-1.5-pro-experimental
# models/gemini-exp-1114
# models/gemini-exp-1121
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
model = ai.GenerativeModel(model_name="models/gemini-1.5-flash")

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
image = Image.open(r"C:\Users\rames\Desktop\VK.webp")
plt.imshow(image)

# %%
prompt = "Describe the scene in the uploaded image in detail."

# %%
response = model.generate_content([image,prompt])
print(response.text)
# Out:
# Close-up view of Virat Kohli, a prominent Indian cricketer, in action during a match.
#
#
# Here's a breakdown of the image:
#
# * **Virat Kohli:** He is the central focus, shown from the chest up and slightly angled, powerfully swinging his cricket bat. He's wearing the Indian national cricket team's uniform, which is predominantly blue with orange accents on the shoulders and sleeves. The "INDIA" lettering is visible on his jersey. His helmet is on, and he's wearing batting gloves. A tattoo is partially visible on his left arm.
#
# * **The Bat:** A MRF Genius cricket bat is prominently featured, held firmly in his grip. The brand name is clearly visible.
#
# * **The Setting:** The background is blurred but shows a cricket field with signage partially visible. The colors suggest a bright, possibly sunny day.  Part of a pink and white sign is blurred in the top background. The lower background shows a part of a red and white sign.
#
# * **The Ball:** A white cricket ball is visible in the lower-middle section of the image, seemingly in motion.
#
# The overall impression is one of intense action and focus, typical of a cricket match. The image is sharp and well-lit, focusing on Kohli's intense concentration and the dynamic movement of the game.

# %%
prompt_1 = "Identify objects or obstacles within the image and highlight them, offering insights to enhance user safety and situational awareness."

# %%
response = model.generate_content([image,prompt_1])
print(response.text)
# Out:
# Here's a description of the image and some safety considerations, although there aren't any direct safety hazards presented:
#
# The image shows Virat Kohli, a famous Indian cricketer, in action. He's wearing the Indian national team's uniform, a helmet, and batting gloves.  He's mid-swing, deeply focused on the game.  The background is a blurred-out cricket stadium, with some signage partially visible.  A cricket ball is visible in the air, seemingly just having been hit.  The focus is entirely on Kohli and his action.
#
# **Safety Considerations (Indirect):**
#
# * **Sports Safety:** While the image doesn't show any immediate danger, it depicts a high-impact sport.  Cricket involves fast-moving balls and potential collisions between players.  Protective gear, like Kohli's helmet and gloves, is crucial for player safety.  Spectators at cricket matches should also be aware of potential risks from stray balls and follow stadium safety guidelines.
#
# * **General Stadium Safety:** The blurred background hints at a crowd, implying the potential for large gatherings at the stadium.  Standard stadium safety procedures (emergency exits, crowd control, etc.) are assumed, but the image itself doesn't offer evidence.
#
#
# In summary, the image is of a sporting event; while the photo itself presents no immediate safety concerns, it implies potential safety considerations related to the sport and the environment in which the event occurs.

# %%
prompt = """
    Analyze the image and provide the following guidance:
    1. Identify the items in the image.
    2. If any labels are visible, read them.
    3. Provide context-specific information such as categorizing the items (e.g., food items, books, etc.) and suggesting tasks or actions related to them.
    """

# %%
response = model.generate_content([image,prompt])
print(response.text)
# Out:
# Here's an analysis of the image:
#
# **1. Items in the Image:**
#
# * **Virat Kohli:** The prominent figure is the Indian cricketer Virat Kohli.
# * **Cricket Bat:** A wooden cricket bat with the "MRF Genius" label is clearly visible.
# * **Cricket Ball:** A white cricket ball is in flight.
# * **Cricket Helmet:** Kohli is wearing a cricket helmet with the Indian flag insignia.
# * **Cricket Gloves:**  Kohli is wearing batting gloves.
# * **Cricket Uniform:** He is wearing an Indian national cricket team uniform.  The word "INDIA" is prominently displayed on his jersey.
# * **Background:** A blurred background suggests a cricket stadium with signage, partially visible.
#
#
# **2. Visible Labels:**
#
# * **MRF Genius:** This is the brand name printed on the cricket bat.
# * **INDIA:** This is displayed on Virat Kohli's jersey, indicating the country he represents.
#
#
# **3. Context-Specific Information:**
#
# * **Categorization:** The items fall under the category of sports equipment (cricket bat, ball, helmet, gloves, uniform) and a person (sportsperson).
# * **Tasks/Actions:**
#     * **Playing Cricket:** The image depicts Virat Kohli in the act of playing cricket, specifically batting.
#     * **Analyzing Technique:** The image could be used to analyze his batting stance, grip, and swing.  Coaches might use this for instructional purposes.
#     * **Marketing/Advertising:** The image could be used in advertising for MRF cricket bats or for promotional materials related to Virat Kohli or the Indian cricket team.
#     * **Sports Reporting/News:**  The image could accompany news articles about a particular match or Kohli's career.
#     * **Creating Fan Memorabilia:** The image can be used to create posters, wallpapers, and other fan-related items.
#
#
# In short, the image is a dynamic action shot of Virat Kohli playing cricket, showcasing his skills and equipment.  Its use cases span various aspects of the sport, marketing, and media.
